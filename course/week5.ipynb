# %% [markdown]
# # Week 5: Functions and Modules
#
# **Lesson:** Defining and calling functions, function parameters, return values, importing modules
#
# ### Activity Ideas:
# 1. Create a simple "Choose Your Adventure" game, allowing the user to make different choices using functions for each choice.
# 2. Build a Super Smash Bros. themed character selector, using functions to return a random character and their signature move.
# 3. Create a Dungeons & Dragons character stat roller, using functions to roll dice, generate ability scores, and choose a race/class.
# 4. Design a simple text-based combat game, using different functions for player actions (attack, defend, run). Incorporate Dungeons & Dragons-inspired elements.
# 5. Create a mini trivia game about video games, using functions for questions, answers, and keeping score. Include questions about Super Smash Bros. and Dungeons & Dragons.
#
# ## Activity: "Choose Your Adventure" Game
#
# In this activity, you will create a simple "Choose Your Adventure" game, allowing the user to make different choices using functions for each choice.
#
# ```python
# # Choose Your Adventure Game
# # A simple text-based game where the user makes choices to navigate through an adventure
#
# def start_game():
#     print("Welcome to the Choose Your Adventure Game!")
#     print("You wake up in a mysterious forest with two paths ahead. Which path do you choose?")
#     print("1. Path of Shadows")
#     print("2. Path of Light")
#     choice = input("Enter your choice (1 or 2): ")
#
#     if choice == "1":
#         path_of_shadows()
#     elif choice == "2":
#         path_of_light()
#     else:
#         print("Invalid choice. Please try again.")
#         start_game()
#
# def path_of_shadows():
#     print("You chose the Path of Shadows. As you walk deeper into the forest, you encounter a pack of wolves.")
#     print("What do you do?")
#     print("1. Fight the wolves")
#     print("2. Try to sneak past them")
#     choice = input("Enter your choice (1 or 2): ")
#
#     if choice == "1":
#         fight_wolves()
#     elif choice == "2":
#         sneak_past_wolves()
#     else:
#         print("Invalid choice. Please try again.")
#         path_of_shadows()
#
# def path_of_light():
#     print("You chose the Path of Light. As you walk through the forest, you come across a sparkling lake.")
#     print("What do you do?")
#     print("1. Take a refreshing swim")
#     print("2. Investigate the lake further")
#     choice = input("Enter your choice (1 or 2): ")
#
#     if choice == "1":
#         take_swim()
#     elif choice == "2":
#         investigate_lake()
#     else:
#         print("Invalid choice. Please try again.")
#         path_of_light()
#
# # Other function definitions and game logic go here...
#
# # Start the game
# start_game()
# ```
